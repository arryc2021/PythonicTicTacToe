# %% [markdown]
# <a href="https://colab.research.google.com/github/arryc2021/PythonicTicTacToe/blob/main/TicTacToe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def print_board(board):
    for row in board:
        print(" | ".join(row))
        print("-" * 5)

def check_win(board, player):
    for row in board:
        if all([cell == player for cell in row]):
            return True
    for col in range(3):
        if all([board[row][col] == player for row in range(3)]):
            return True
    if all([board[i][i] == player for i in range(3)]):
        return True
    if all([board[i][2 - i] == player for i in range(3)]):
        return True
    return False

def is_draw(board):
    return all(cell != " " for row in board for cell in row)

def tic_tac_toe():
    board = [[" " for _ in range(3)] for _ in range(3)]
    current_player = "X"

    while True:
        print_board(board)
        print(f"Player {current_player}'s turn")
        row = int(input("Enter row (0, 1, 2): "))
        col = int(input("Enter column (0, 1, 2): "))

        if board[row][col] != " ":
            print("Invalid move, spot taken!")
            continue

        board[row][col] = current_player

        if check_win(board, current_player):
            print_board(board)
            print(f"Player {current_player} wins!")
            break

        if is_draw(board):
            print_board(board)
            print("It's a draw!")
            break

        current_player = "O" if current_player == "X" else "X"

if __name__ == "__main__":
    tic_tac_toe()
# Out:
#   |   |
# -----
#   |   |
# -----
#   |   |
# -----
# Player X's turn
# Enter row (0, 1, 2): 2
# Enter column (0, 1, 2): 1
#   |   |
# -----
#   |   |
# -----
#   | X |
# -----
# Player O's turn
# Enter row (0, 1, 2): 1
# Enter column (0, 1, 2): 2
#   |   |
# -----
#   |   | O
# -----
#   | X |
# -----
# Player X's turn
# Enter row (0, 1, 2): 0
# Enter column (0, 1, 2): 1
#   | X |
# -----
#   |   | O
# -----
#   | X |
# -----
# Player O's turn
# Enter row (0, 1, 2): 1
# Enter column (0, 1, 2): 1
#   | X |
# -----
#   | O | O
# -----
#   | X |
# -----
# Player X's turn
# Enter row (0, 1, 2): 1
# Enter column (0, 1, 2): 0
#   | X |
# -----
# X | O | O
# -----
#   | X |
# -----
# Player O's turn
# Enter row (0, 1, 2): 1
# Enter column (0, 1, 2): 1
# Invalid move, spot taken!
#   | X |
# -----
# X | O | O
# -----
#   | X |
# -----
# Player O's turn
# Enter row (0, 1, 2): 0
# Enter column (0, 1, 2): 0
# O | X |
# -----
# X | O | O
# -----
#   | X |
# -----
# Player X's turn
# Enter row (0, 1, 2): 0
# Enter column (0, 1, 2): 1
# Invalid move, spot taken!
# O | X |
# -----
# X | O | O
# -----
#   | X |
# -----
# Player X's turn
# Enter row (0, 1, 2): 1
# Enter column (0, 1, 2): 2
# Invalid move, spot taken!
# O | X |
# -----
# X | O | O
# -----
#   | X |
# -----
# Player X's turn
# Enter row (0, 1, 2): 2
# Enter column (0, 1, 2): 0
# O | X |
# -----
# X | O | O
# -----
# X | X |
# -----
# Player O's turn
# Enter row (0, 1, 2): 2
# Enter column (0, 1, 2): 2
# O | X |
# -----
# X | O | O
# -----
# X | X | O
# -----
# Player O wins!
